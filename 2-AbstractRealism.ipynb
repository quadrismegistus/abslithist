# %% [markdown]
# # Counting

# %%
from abslithist.words import *
from abslithist.realism import *

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Testing

# %%
txt="""It was a dark and stormy night; the rain fell in torrents—except at occasional intervals, when it was checked by a violent gust of wind which swept up the streets (for it is in London that our scene lies), rattling along the housetops, and fiercely agitating the scanty flame of the lamps that struggled against the darkness."""

# %%
# import lltk
# txt=lltk.load('CanonFiction').texts()[0].txt

# %%
# pd.DataFrame(get_norms_for_counting())
def test_counts(txt):
    return pd.DataFrame(
        count_absconc(txt)
    ).sort_values('num_conc',ascending=False)

# %%
# test_counts(txt)

# %% [markdown]
# ### Executing

# %%
# source(count_absconc_corpus)

# %%
# count_absconc_corpus('CanonFiction',num_proc=4)

# %% [markdown]
# ## Plotting

# %%
df=load_data_for_plotting()

# %%
do_plot_fiction(df,valtype='abs-conc',standardize=False,min_y=-400,max_y=400,jitter=1)
# Out:
# >> Plotting...
# <ggplot: (8729888059849)>

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# ## Analysis

# %%
dfall=pd.read_csv('data/counts/data.absconc.CanonFiction.csv').dropna()
dfall['abs/conc']=dfall['num_abs']/dfall['num_conc']
dfall['abs-conc']=dfall['num_abs']-dfall['num_conc']
df=dfall[dfall.num_total==max(dfall.num_total)].sort_values('abs/conc')
df

# %%
# df[df.id=='Julian of Norwich.Divine Love']

# %%
dftext=df[df.period!='orig'].groupby('id').median().sort_values('abs-conc')
dftext

# %%
dftext.sort_values('num_types')

# %%
df.sort_values('num_types')

# %%
dftext.plot(x='num_abs',y='num_types',kind='scatter')

# %%
df[df.id=='chadwyck.Anon.The_Duke_of_Alanccedilon.0889'].source.value_counts()

# %%
import lltk
C=lltk.load('CanonFiction')
dftextm=dftext.join(C.metadata.set_index('id'))

# %%
dftextm.query('1500<=year<=2020').plot(x='year',y='abs/conc',kind='scatter',logy=True)

# %%
# print(C.textd['chadwyck.Austen.Lady_Susan_in_The_Works_o.1091'].txt)

# %%
ladysusan=df[df.id=='chadwyck.Austen.Lady_Susan_in_The_Works_o.1091'].sort_values('slice')
ladysusan

# %%
ladysusan.boxplot('num_abs','slice')#,kind='boxplot')

# %%
duke=df[df.id=='chadwyck.Anon.The_Duke_of_Alanccedilon.0889'].sort_values('slice')
duke

# %%
# duke.sort_values('num_abs')

# %%
duke.boxplot('num_abs','slice')

# %%
pamela=df[df.id=='Richardson.Pamela']
pamela

# %%
pamela[(pamela.source=='MT-Conc') & (pamela.period!='orig')].boxplot('num_conc','slice')

# %%
df[(df.source=='MRC-Conc') & (df.num_total>=10000)].groupby('id').median().sort_values('abs/conc')

# %%
df[(df.source!='LSN-Hapt') & (df.num_total>=1000)].groupby('id').median().sort_values('abs/conc')

# %%
df.sort_values('num_total')
