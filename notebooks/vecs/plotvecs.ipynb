# %%
# Plot vecs

# %%
# Quick contrasts

# %%
import sys; sys.path.append('../..')
from abslithist import *
from abslithist.words import *

# %%
norms = get_allnorms()
norms
# Out:
#           Abs-Conc.LSN-Hapt.C16  Abs-Conc.LSN-Imag.C16  Abs-Conc.MRC-Conc.C16  \
# word
# I                           NaN                    NaN                    NaN
# Inf                         NaN                    NaN                    NaN
# a'ch                        NaN                    NaN                    NaN
# a'mighty                    NaN                    NaN                    NaN
# a'most                      NaN                    NaN                    NaN
# ...                         ...                    ...                    ...
# ụyr                    0.745248               0.997725               1.068004
# NaN                    0.089321               0.313425               0.556062
# NaN                   -0.887439              -0.709960              -1.086186
# NaN                    0.089321               0.313425               0.556062
# NaN                   -0.887439              -0.709960              -1.086186
#
# ...

# %%
corrs=norms.corr()

# %%
corrs['Woman-Man.MultiWords.median'].sort_values(ascending=False).head(10)
# Out:
# Woman-Man.MultiWords.median     1.000000
# Woman-Man.MultiWords.C19        0.878308
# Woman-Man.MultiWords.C20        0.876990
# Woman-Man.MultiWords.C16        0.872965
# Woman-Man.MultiWords.C17        0.842877
# Woman-Man.MultiWords.C18        0.817013
# Woman-Man.SingleWords.median    0.805148
# Woman-Man.SingleWords.C19       0.742331
# Woman-Man.SingleWords.C17       0.723275
# Woman-Man.SingleWords.C16       0.706678
# Name: Woman-Man.MultiWords.median, dtype: float64

# %%
abs_conc = {
    
}
