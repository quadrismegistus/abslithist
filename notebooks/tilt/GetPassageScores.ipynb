# %%
import sys; sys.path.append('../..')
from abslithist import *
from abslithist.realism import *

# %%
scoredir='../../data/scores/bytext3'
scorepaths=[
    os.path.join(root,fn)
   for root,dirs,fns in os.walk(scoredir)
   for fn in fns
   if fn.endswith('.ft')
]
len(scorepaths),scorepaths[0]
# Out:
# (1807, '../../data/scores/bytext3/CanonFiction/markmark.Sukenick.Up.1636.ft')

# %%
def load_scores_bytext(ifn,rd={'_':' ', '|':'\n'}):
    if not os.path.exists(ifn): return
    df=pd.read_feather(ifn).set_index('i_tok')
    df['tok']=df['tok'].apply(lambda w: rd.get(w,w))
    df['tokl']=df['tokl'].apply(lambda w: rd.get(w,w))
    return df
    
# test
for t in C.texts():
    ifn=os.path.join(scoredir,t.corpus.name,t.id+'.ft')
    df=load_scores_bytext(ifn)
    if df is not None: break
df
# Out:
#         i_para  i_sent  i_word     tok    tokl  is_punct  is_recog       val
# i_tok
# 0            0       0       0  Things  things         0         0       NaN
# 1            0       0       0                         1         0       NaN
# 2            0       0       1    Fall    fall         0         1 -0.162164
# 3            0       0       1                         1         0       NaN
# 4            0       0       2   Apart   apart         0         0       NaN
# ...        ...     ...     ...     ...     ...       ...       ...       ...
# 106601      26    3781   51334   Niger   niger         0         0       NaN
# 106602      26    3781   51334       .       .         1         0       NaN
# 106603      26    3782   51335     The     the         0         0       NaN
# 106604      26    3782   51335                         1         0       NaN
# 106605      26    3782   51336     End     end         0         0       NaN
#
# [106606 rows x 8 columns]

# %%
def divide_by_sent_windows(df,nmin=50):
    o=[]
    ipsg=0
    nnow=0
    df=df.sort_values(['i_para','i_sent'])
    for (para_i,sent_i),dfg in sorted(df.groupby(['i_para','i_sent'])):
        o+=[ipsg for n in range(len(dfg))]
        nnow+=dfg.is_recog.sum()        
        if nnow>=nmin:
            ipsg+=1
            nnow=0
    return o

# test
df['i_psg']=divide_by_sent_windows(df)
df
# Out:
#         i_para  i_sent  i_word     tok    tokl  is_punct  is_recog       val  \
# i_tok
# 0            0       0       0  Things  things         0         0       NaN
# 1            0       0       0                         1         0       NaN
# 2            0       0       1    Fall    fall         0         1 -0.162164
# 3            0       0       1                         1         0       NaN
# 4            0       0       2   Apart   apart         0         0       NaN
# ...        ...     ...     ...     ...     ...       ...       ...       ...
# 106601      26    3781   51334   Niger   niger         0         0       NaN
# 106602      26    3781   51334       .       .         1         0       NaN
# 106603      26    3782   51335     The     the         0         0       NaN
# 106604      26    3782   51335                         1         0       NaN
# 106605      26    3782   51336     End     end         0         0       NaN
#
#         i_psg
# i_tok
# ...

# %%
df.tail(50)
# Out:
#         i_para  i_sent  i_word           tok          tokl  is_punct  \
# i_tok
# 106556      26    3781   51313                                     1
# 106557      26    3781   51314           had           had         0
# 106558      26    3781   51314                                     1
# 106559      26    3781   51315       already       already         0
# 106560      26    3781   51315                                     1
# 106561      26    3781   51316        chosen        chosen         0
# 106562      26    3781   51316                                     1
# 106563      26    3781   51317           the           the         0
# 106564      26    3781   51317                                     1
# 106565      26    3781   51318         title         title         0
# 106566      26    3781   51318                                     1
# 106567      26    3781   51319            of            of         0
# ...

# %%
def detokenize_psg(psgdf,valcol='val'):
    psgdf=psgdf.sort_values('i_tok')
#     txt=''.join(psgdf.tok)
    txt=' '.join(
        ''.join(sentdf.tok)
        for i,sentdf in sorted(psgdf.groupby('i_sent'))
    )
    data=odx={'txt':txt}
    words=[x for x in psgdf[psgdf.is_punct==0].tokl]
    recogwords=[x for x in psgdf[psgdf.is_recog==1].tokl]
    
    data['i_tok']=min(psgdf.index)
    for icol in ['i_para','i_sent','i_word']:
        data[icol]=min(psgdf[icol])

    data['num_word']=len(words)
    data['num_word_types']=len(set(words))
    data['ttr']=data['num_word_types'] / data['num_word'] if data['num_word'] else np.nan

    data['num_recog']=len(recogwords)
    data['num_recog_types']=len(set(recogwords))
    data['ttr_recog']=data['num_recog_types'] / data['num_recog'] if data['num_recog'] else np.nan


    data['val_mean']=psgdf['val'].mean()
    data['val_median']=psgdf['val'].median()
    data['val_stdev']=psgdf['val'].std()

    return pd.DataFrame([odx])

# %%
for i,dfg in df.groupby('i_psg'): break
detokenize_psg(dfg)
# Out:
#                                                  txt  i_tok  i_para  i_sent  \
# 0  Things Fall Apart\n\nChinua Achebe\n\n\n\nCHAP...      0       0       0
#
#    i_word  num_word  num_word_types       ttr  num_recog  num_recog_types  \
# 0       0       169             106  0.627219         51               48
#
#    ttr_recog  val_mean  val_median  val_stdev
# 0   0.941176    0.2429    0.423628   0.814174

# %%
dfpsgs=pmap_groups(
    detokenize_psg,
    df.groupby('i_psg'),
    num_proc=1
)
print(dfpsgs.iloc[-1].txt)
# Out:
# Mapping detokenize_psg [x1]: 100%|██████████| 259/259 [00:01<00:00, 208.11it/s]
# In the many years in which he had toiled to bring civilization to different parts of Africa he had learned a number of things. One of them was that a District Commissioner must never attend to such undignified details as cutting a hanged man from the tree. Such attention would give the natives a poor opinion of him. In the book which he planned to write he would stress that point. As he walked back to the court he thought about that book. Every day brought him some new material. The story of this man who had killed a messenger and hanged himself would make interesting reading. One could almost write a whole chapter on him. Perhaps not a whole chapter but a reasonable paragraph, at any rate. There was so much else to include, and one must be firm in cutting out details. He had already chosen the title of the book, after much thought:
#
#
# ...

# %%
dfpsgs.sort_values('val_mean')
# Out:
#                                                      txt  i_tok  i_para  \
# i_psg
# 215    These moods descended on her suddenly and for ...  88191      20
# 196    But stories were already gaining ground that t...  80188      18
# 226    And he had hoped that Okonkwo would be happy t...  93219      21
# 197    These outcasts, or osu, seeing that the new re...  80584      18
# 223    "That is exactly what I am saying. The head of...  91663      21
# ...                                                  ...    ...     ...
# 122    A palm-oil lamp gave out yellowish light. With...  49651      10
# 54     She pulled again and it came off. "Ekwefi!" a ...  21354       4
# 92     She wore a black necklace which hung down in t...  37012       7
# 83     Now and then a cold shiver descended on his he...  32608       7
# 84     He searched in it for his snuff-bottle. It was...  32999       7
#
#        i_sent  i_word  num_word  num_word_types       ttr  num_recog  \
# i_psg
# ...

# %%
def printextrm(dfpsgs):
    printm('### Most abstract')
    showpsg(dfpsgs.sort_values('val_mean').iloc[0].txt)
    printm('### Most concrete')
    showpsg(dfpsgs.sort_values('val_mean').iloc[-1].txt)

printextrm(dfpsgs)
# Out:
# ### Most abstract
# ...

# %%
def dopath(inp):
    try:
        path,ofn=inp

        # load scores for text
        df=load_scores_bytext(path)

        # add psg boundaries
        df['i_psg']=divide_by_sent_windows(df)

        # summarize by psg
        dfpsgs=pmap_groups(
            detokenize_psg,
            df.groupby('i_psg'),
            num_proc=1,
            progress=False,
        )

        # save
        odir=os.path.dirname(ofn)
        if not os.path.exists(odir): os.makedirs(odir)
        dfpsgs.to_csv(ofn)    
        del dfpsgs
    #     return dfpsgs
    except Exception:
        pass

# %%
objs=[(spath, spath.replace('bytext','bypsg').replace('.ft','.csv')) for spath in scorepaths]
objs=[obj for obj in objs if not os.path.exists(obj[1])]
# dfpsgs=dopath(random.choice(objs))
# dfpsgs
len(objs)
# Out:
# 1807

# %%
res = pmap(
    dopath,
    objs,
    desc='Detokenizing passages across all texts',
    num_proc=4
)
# Out:
# Detokenizing passages across all texts [x4]: 100%|██████████| 1807/1807 [34:27<00:00,  1.14s/it]
