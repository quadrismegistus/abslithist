# %%
import sys; sys.path.append('../..')
from abslithist import *

# %%
# Out:
# ['BAD_SOURCES',
#  'BY_SENTENCE',
#  'Bunch',
#  'C',
#  'CORPUS',
#  'COUNT_DIR',
#  'COUNT_WINDOW_LEN',
#  'Counter',
#  'DEFAULT_ABSCONC_CONTRAST',
#  'DEFAULT_ABS_FIELD',
#  'DEFAULT_CONC_FIELD',
#  'DEFAULT_CORPUS',
#  'DEFAULT_NEITHER_FIELD',
#  'DEFAULT_NUM_PROC',
#  'DIST_DIR',
#  'DTOK_TREEBANK',
#  'ENGLISH',
#  'FICTION_CORPUS_NAME',
#  'FIELD_DIR',
#  'FUNC_CMDS',
#  'HOME',
#  'In',
#  'JITTER',
#  'LIT_ROOT',
#  'LLTK_ROOT',
#  'MANIFEST',
#  'MDETOK',
#  'MIN_COUNT_MODEL',
#  'MODEL_DIR',
#  'MODEL_MIN_COUNT',
#  'MODEL_NUM_DIM',
#  'MODEL_NUM_SKIPS',
#  'MODEL_PERIOD_LEN',
#  'MODERNIZE_SPELLING',
#  'NORM_CONTRASTS',
#  'OCRCORREX',
#  'Out',
#  'PARALLELIZED_CMDS',
#  'PART_REFERRING_CMDS',
#  'PATH_BASE_CONF',
#  'PATH_DATA',
#  'PATH_DEFAULT_CONF',
#  'PATH_DEFAULT_DATA',
#  'PATH_FIGS',
#  'PATH_FIGS2',
#  'PATH_HERE',
#  'PATH_IMGCONVERT',
#  'PATH_LLTK_HOME',
#  'PATH_LLTK_HOME_DATA',
#  'PATH_LLTK_REPO',
#  'PATH_MANIFEST_GLOBAL',
#  'PATH_MODELS',
#  'PATH_NAMES',
#  'PATH_NORMS',
#  'PATH_PSGS',
#  'PATH_PSG_CURRENT',
#  'PATH_ROOT',
#  'PATH_SCORE_CURRENT',
#  'PATH_SPELLING_D',
#  'PATH_STOPWORDS',
#  'PATH_VECFIELDS',
#  'PATH_VECFIELDS_PKL',
#  'PATH_VECNORMS',
#  'PERIODS_FOR_COUNTING',
#  'PLOTVERSION',
#  'PSGS_DIR',
#  'PSG_NORMS',
#  'PSG_PERIODS',
#  'PSG_SOURCES',
#  'QNUM',
#  'REMOVE_STOPWORDS_IN_WORDNORMS',
#  'REPLACEMENTS',
#  'REPLACEMENTS_b',
#  'SENTENCE_TOKENIZER',
#  'SLINGSHOT_FN',
#  'SOURCES',
#  'SOURCES_FOR_COUNTING',
#  'SOURCES_FOR_PLOTTING',
#  'SOURCE_DIR',
#  'SPELLINGD',
#  'SPELLING_D',
#  'STOPWORDS',
#  'SkipgramsSampler',
#  'URL_DEFAULT_DATA',
#  'USER_HOME',
#  'USE_COLOR',
#  'V2S',
#  'VECNORMS_FN',
#  'VECNORMS_FN_PRE',
#  'VERSION',
#  'WORD2POS',
#  'WORDDB_FN',
#  'WORDLISTS',
#  'WORDS',
#  'ZCUT',
#  'ZCUT_NORMS_ORIG',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'abslithist',
#  'absolute_import',
#  'add_series_to_norms',
#  'adjust_text_dict',
#  'analyze_as_dist',
#  'barplot',
#  'basic_detokenizer',
#  'bigrams',
#  'biny',
#  'binz',
#  'binz2',
#  'breaks',
#  'camel2snake_case',
#  'check_copy_file',
#  'check_make_dir',
#  'check_make_dirs',
#  'check_move_file',
#  'cleanhtml',
#  'cleanstrip',
#  'cleantxt',
#  'cloud_list',
#  'cloud_share_all',
#  'codecs',
#  'colors',
#  'compare_psgs',
#  'compare_psgs_show',
#  'compute_vec2vec_dists',
#  'compute_vecfields',
#  'compute_vector',
#  'compute_word2field_dists',
#  'config',
#  'config_obj2dict',
#  'configparser',
#  'configure_prompt',
#  'copyfileobj',
#  'corr_allnorms',
#  'corr_norms',
#  'corr_orignorms',
#  'corr_vecnorms',
#  'corr_with_cluster',
#  'count_absconc',
#  'count_absconc_corpus',
#  'count_absconc_json',
#  'count_absconc_path',
#  'count_absconc_path_psg',
#  'count_absconc_psg',
#  'counts',
#  'crunch',
#  'csv',
#  'cutoff',
#  'd2ll',
#  'd2str',
#  'darcy_full',
#  'datatype',
#  'datetime',
#  'dd2ld',
#  'decideifabs',
#  'defaultdict',
#  'density',
#  'detokenize',
#  'detokenize_treebank',
#  'df2xml',
#  'dfall_cols',
#  'display_source',
#  'dist',
#  'dist2norms',
#  'dl2ld',
#  'dld2ld',
#  'do_configs',
#  'do_plot_fiction',
#  'do_pmap_group',
#  'download',
#  'download_curl',
#  'download_default_data',
#  'download_pycurl',
#  'download_tqdm',
#  'download_tqdm2',
#  'download_wget',
#  'draw_bokeh',
#  'edityear',
#  'embeddings',
#  'exit',
#  'expanduser',
#  'extract',
#  'facet2label',
#  'factor',
#  'fastdist',
#  'ferrars_full',
#  'fields',
#  'filesize',
#  'filter_model',
#  'filter_norms',
#  'find_nth_character',
#  'fn2ld',
#  'format_norms_as_long',
#  'freqs',
#  'gather_scores_corpus',
#  'gen_all_models',
#  'gen_all_skipgrams',
#  'gen_bookpassages',
#  'gen_model',
#  'gen_models',
#  'gen_models_corpus',
#  'gen_normplots',
#  'gen_norms_brys',
#  'gen_norms_lsn',
#  'gen_norms_mrc',
#  'gen_norms_paivio',
#  'gen_orignorms',
#  'gen_skipgrams_corpus',
#  'gen_top_words_across_models',
#  'gen_vecfields',
#  'gen_vecnorms',
#  'gen_vecnorms_for_model',
#  'gen_vecnorms_for_paths',
#  'gensim',
#  'get_absconc',
#  'get_all_passages',
#  'get_allcontrasts',
#  'get_allfields',
#  'get_allnorms',
#  'get_centroid',
#  'get_config_file_location',
#  'get_contrasts',
#  'get_css',
#  'get_current_dfall_psgs',
#  'get_current_text_scores',
#  'get_density_peak',
#  'get_field2words',
#  'get_fields',
#  'get_fields0',
#  'get_fields_from_norms',
#  'get_fieldvecs_in_model',
#  'get_ipython',
#  'get_lltk_id',
#  'get_misccontrasts',
#  'get_model_paths',
#  'get_norms_for_counting',
#  'get_num_lines',
#  'get_numlines',
#  'get_ocr_corrections',
#  'get_origcontrasts',
#  'get_origfields',
#  'get_orignorms',
#  'get_path_abs',
#  'get_psg_norms',
#  'get_savedir',
#  'get_sentence_tokenizer',
#  'get_slices',
#  'get_spelling_modernizer',
#  'get_stopwords',
#  'get_subcontrasts',
#  'get_the_getters',
#  'get_url_or_path',
#  'get_veccontrasts',
#  'get_vecfields',
#  'get_vecnorms',
#  'get_vecnorms_fns',
#  'get_word2fields',
#  'get_word2pos',
#  'get_word2pos_df',
#  'get_word_window',
#  'get_wordlist',
#  'gleanPunc2',
#  'goog2tsv',
#  'gzip',
#  'hashstr',
#  'header',
#  'header_absconc',
#  'human_format',
#  'imp',
#  'in_jupyter',
#  'index',
#  'init_css',
#  'inspect',
#  'iter_filename',
#  'iter_move',
#  'iter_sentences',
#  'json',
#  'jsonlines',
#  'kmeans',
#  'l2str',
#  'ld2dd',
#  'ld2dl',
#  'ld2dld',
#  'ld2html',
#  'ld2keys',
#  'ld2ll',
#  'ld2str',
#  'ld_resample',
#  'levenshtein',
#  'limcols',
#  'linreg',
#  'll2str',
#  'lltk',
#  'load_config',
#  'load_data_for_plotting',
#  'load_default_config',
#  'load_english',
#  'load_global_config',
#  'load_model',
#  'load_stopwords',
#  'load_user_config',
#  'loadjson',
#  'marianne_full',
#  'math',
#  'measure_fields',
#  'measure_ocr_accuracy',
#  'models',
#  'modernize_spelling_in_txt',
#  'moses_detokenize',
#  'newnewsource',
#  'newpolyfit',
#  'newsource',
#  'ngram',
#  'nlp',
#  'nltk',
#  'noPunc',
#  'now',
#  'np',
#  'os',
#  'p9',
#  'pandarallel',
#  'passages',
#  'pd',
#  'pearsonr',
#  'periodize',
#  'phrase2variants',
#  'pickle',
#  'plot_allnorms',
#  'plot_densityz',
#  'plot_distro',
#  'plot_fiction',
#  'plot_norms',
#  'plot_orignorms',
#  'plot_vecnorms',
#  'plots',
#  'pmap',
#  'pmap_df',
#  'pmap_do',
#  'pmap_groups',
#  'pmap_iter',
#  'ppath',
#  'pprint',
#  'prebreak_cuts',
#  'prebreaks',
#  'print_config',
#  'print_function',
#  'printimg',
#  'printm',
#  'printpsg',
#  'printx',
#  'product',
#  'psg2df',
#  'quit',
#  'random',
#  'range',
#  're',
#  'read',
#  'read_csv_with_pandas',
#  'read_df',
#  'read_ld',
#  'readgen',
#  'readgen_csv',
#  'readgen_jsonl',
#  'realism',
#  'register_cell_magic',
#  'regressions',
#  'remove_duplicates',
#  'requests',
#  'reset_index',
#  'restrict_w2v',
#  'rpath',
#  'sample',
#  'sample_passages',
#  'save_bookpassages',
#  'save_df',
#  'save_skipgrams_from_paths',
#  'saveextremes',
#  'score_corpus',
#  'scores',
#  'shapes',
#  'show_allcontrasts',
#  'show_contrasts',
#  'show_fields',
#  'show_origcontrasts',
#  'show_veccontrasts',
#  'showpsg',
#  'showpsg_t',
#  'shutil',
#  'six',
#  'sizeof_fmt',
#  'skipgrams',
#  'sl',
#  'slice',
#  'slingshot_cmd_starter',
#  'slingshot_py',
#  'smf',
#  'source',
#  'spcr',
#  'spellingd',
#  'splitkeepsep',
#  'standard2variant',
#  'stats',
#  'stopwords',
#  'strmake',
#  'symlink',
#  'sys',
#  'tagname2tagtup',
#  'tempfile',
#  'time',
#  'tknz',
#  'to_cent',
#  'to_field_period',
#  'to_halfcent',
#  'to_html',
#  'to_mdw',
#  'to_prodigy',
#  'to_singular',
#  'to_tf',
#  'to_tfidf',
#  'tokenize',
#  'tokenize_fast',
#  'tokenize_sentences',
#  'tokenize_sentences_nlp',
#  'toks2str',
#  'tools',
#  'tqdm',
#  'tqdm_read_csv',
#  'tsne',
#  'tsv2ld',
#  'untar',
#  'unzip',
#  'urllib',
#  'valid_args_for',
#  'valtype2label',
#  'variant2standard',
#  'warnings',
#  'which',
#  'willoughby_full',
#  'worddb',
#  'worddf',
#  'words',
#  'write',
#  'write2',
#  'write_and_run',
#  'write_ld',
#  'write_ld2',
#  'writegen',
#  'writegen_jsonl',
#  'writegen_orig',
#  'writegengen',
#  'xls2dld',
#  'xls2ld',
#  'xlsx2ld',
#  'xopen',
#  'yank',
#  'year2period',
#  'yield_sentences_from_text',
#  'yield_skipgrams_from_paths',
#  'yield_skipgrams_from_text',
#  'zeropunc',
#  'zfy',
#  'zip',
#  'zipfile',
#  'zscore']

# %%
def iter_sentences(txt):
    yield from tokenize_sentences(txt)

# %%
tokenize_fast("Hello—world.")
# Out:
# ['hello', 'world']
