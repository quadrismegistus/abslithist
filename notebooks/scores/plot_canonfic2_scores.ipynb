# %% [markdown]
# # Plotting canon fic

# %%
import sys; sys.path.append('../..')
from abslithist.words import *
from abslithist.realism import *

import plotnine as p9
JITTER=0
VERSION='v2'
p9.options.dpi=600
p9.options.figure_size=(11.7,8.3)
factor=2.5
cutoff=1600
spcr=40
prebreak_cuts=[1500,1000,0,-1000]
prebreaks=[cutoff - (spcr*(i+1)) for i in range(len(prebreak_cuts))]
breaks=[1600,1700,1800,1900,2000]


colors = {'Allegory': '#33a02c',
 'Dialogue': '#1f78b4',
 'Epic': '#b2df8a',
 'Novel': '#a6cee3',
 'Novella': '#fb9a99',
 'Other': '#e31a1c',
 'Pastoral': '#fdbf6f',
 'Picaresque': '#ff7f00',
 'Romance': '#cab2d6',
 'Satire': '#6a3d9a',
 'Tale': '#94945a',
 'Unknown': 'gray',
 'Verse':'#b15928'}

shapes =  {'Allegory': 'd',
 'Dialogue': '8',
 'Epic': '<',
 'Novel': 'o',
 'Novella': 'v',
 'Other': 'h',
 'Pastoral': 'D',
 'Picaresque': '>',
 'Romance': 's',
 'Satire': 'x',
 'Tale': '+',
 'Unknown': '.',
 'Verse':'*'}


# function to compact years
def edityear(y,spcr=spcr,cutoff=cutoff,breaks=prebreak_cuts):
    if y>=cutoff: return y
    for i,brk in enumerate(breaks):
        if y>brk:
            brk0=breaks[i-1] if i-1>=0 else cutoff
            return int((cutoff-(spcr*(i+1))) + ((y-brk)/(brk0-brk))*spcr)

# %%
import lltk,pandas as pd
df=pd.read_feather('../../data/scores/data.canon_fic_scores.v2.ft')
C=lltk.load('CanonFiction')

# %%
from scipy.stats import zscore

# df['median_z']=zscore(df['median'])
df
# Out:
#                                                       id  contrast    source  \
# 0        chadwyck.Haywood.The_Fatal_Secret_a_machin.1041  Abs-Conc  LSN-Hapt
# 1        chadwyck.Haywood.The_Fatal_Secret_a_machin.1041  Abs-Conc  LSN-Imag
# 2        chadwyck.Haywood.The_Fatal_Secret_a_machin.1041  Abs-Conc  MRC-Conc
# 3        chadwyck.Haywood.The_Fatal_Secret_a_machin.1041  Abs-Conc  MRC-Imag
# 4        chadwyck.Haywood.The_Fatal_Secret_a_machin.1041  Abs-Conc   MT-Conc
# ...                                                  ...       ...       ...
# 110259  chadwyck.Ingraham.The_Spanish_Galleon_or_Th.0449  Abs-Conc  MRC-Imag
# 110260  chadwyck.Ingraham.The_Spanish_Galleon_or_Th.0449  Abs-Conc   MT-Conc
# 110261  chadwyck.Ingraham.The_Spanish_Galleon_or_Th.0449  Abs-Conc  PAV-Conc
# 110262  chadwyck.Ingraham.The_Spanish_Galleon_or_Th.0449  Abs-Conc  PAV-Imag
# 110263  chadwyck.Ingraham.The_Spanish_Galleon_or_Th.0449  Abs-Conc    Median
#
#        period      mean    median          sum       std  size
# 0         C16 -0.341868 -0.505875 -1469.007567  0.816953  4297
# 1         C16 -0.504876 -0.683759 -2169.451530  0.860748  4297
# 2         C16 -0.531029 -0.736874 -2281.832301  0.883268  4297
# 3         C16 -0.314584 -0.478982 -1351.766714  0.902743  4297
# 4         C16 -0.647206 -0.813839 -2781.046087  0.828056  4297
# ...       ...       ...       ...          ...       ...   ...
# 110259   orig  0.440203  0.583889  2227.867830  0.851227  5061
# 110260   orig  0.501107  0.576020  4734.454378  1.002769  9448
# 110261   orig  0.318329  0.893047   392.499528  1.006203  1233
# 110262   orig  0.461812  0.841898   577.265569  0.916141  1250
# 110263   orig  0.355375  0.424064  3378.547598  0.832942  9507
#
# [110264 rows x 9 columns]

# %%
# filter
meta=C.meta
#meta.query('corpus_source=="Chadwyck"').nation.value_counts()
# meta=meta[(meta.canon_genre!='') | (meta.corpus_source!='Chadwyck') | (meta.nation!='American')]
meta=meta[(meta.corpus_source!='Chadwyck') | (meta.nation!='American')]
meta
# Out:
#                                                              author  \
# id
# markmark.Achebe.Things_Fall_Apart.1339               Achebe, Chinua
# markmark.Acker.In_Memoriam_to_Identity.1340            Acker, Kathy
# markmark.Adams.The_Hitchhikers_Guide_to.1341    Adams, Douglas Noel
# markmark.Adams.Watership_Down.1342            Adams, Richard George
# Addison.Spectator                                           Addison
# ...                                                             ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                                                              title  \
# id
# markmark.Achebe.Things_Fall_Apart.1339                           Things Fall Apart
# markmark.Acker.In_Memoriam_to_Identity.1340                In Memoriam to Identity
# markmark.Adams.The_Hitchhikers_Guide_to.1341  The Hitchhiker's Guide to the Galaxy
# markmark.Adams.Watership_Down.1342                                  Watership Down
# Addison.Spectator                                                   Spectator (A.)
# ...                                                                            ...
# Unknown.King James Bible.New Testament                               New Testament
# Julian of Norwich.Divine Love                            Revelation of Divine Love
# Bible.Leviticus.KJV                                                      Leviticus
# Bible.Numbers.KJV                                                          Numbers
# Bible.Deuteronomy.KJV                                                  Deuteronomy
#
#                                               year      canon_genre  \
# id
# markmark.Achebe.Things_Fall_Apart.1339        1958           Achebe
# markmark.Acker.In_Memoriam_to_Identity.1340   1990            Acker
# markmark.Adams.The_Hitchhikers_Guide_to.1341  1979           Sci-Fi
# markmark.Adams.Watership_Down.1342            1972
# Addison.Spectator                             1711  “The Spectator”
# ...                                            ...              ...
# Unknown.King James Bible.New Testament        1611
# Julian of Norwich.Divine Love                 1373
# Bible.Leviticus.KJV                           -400
# Bible.Numbers.KJV                             -400
# Bible.Deuteronomy.KJV                         -400
#
#                                              canon_name major_genre  \
# id
# markmark.Achebe.Things_Fall_Apart.1339                        Novel
# markmark.Acker.In_Memoriam_to_Identity.1340                   Novel
# markmark.Adams.The_Hitchhikers_Guide_to.1341                  Novel
# markmark.Adams.Watership_Down.1342
# Addison.Spectator                                             Other
# ...                                                 ...         ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                              setting_elson year_trans  \
# id
# markmark.Achebe.Things_Fall_Apart.1339
# markmark.Acker.In_Memoriam_to_Identity.1340
# markmark.Adams.The_Hitchhikers_Guide_to.1341
# markmark.Adams.Watership_Down.1342
# Addison.Spectator
# ...                                                    ...        ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                              author_id corpus_source  ...  \
# id                                                                    ...
# markmark.Achebe.Things_Fall_Apart.1339                      MarkMark  ...
# markmark.Acker.In_Memoriam_to_Identity.1340                 MarkMark  ...
# markmark.Adams.The_Hitchhikers_Guide_to.1341                MarkMark  ...
# markmark.Adams.Watership_Down.1342                          MarkMark  ...
# Addison.Spectator                                                     ...
# ...                                                ...           ...  ...
# Unknown.King James Bible.New Testament                                ...
# Julian of Norwich.Divine Love                                         ...
# Bible.Leviticus.KJV                                                   ...
# Bible.Numbers.KJV                                                     ...
# Bible.Deuteronomy.KJV                                                 ...
#
#                                              name_last name_middle name_title  \
# id
# markmark.Achebe.Things_Fall_Apart.1339          Achebe
# markmark.Acker.In_Memoriam_to_Identity.1340      Acker
# markmark.Adams.The_Hitchhikers_Guide_to.1341     Adams        Noel
# markmark.Adams.Watership_Down.1342               Adams      George
# Addison.Spectator
# ...                                                ...         ...        ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                                 nation note  \
# id
# markmark.Achebe.Things_Fall_Apart.1339        Nigerian
# markmark.Acker.In_Memoriam_to_Identity.1340   American
# markmark.Adams.The_Hitchhikers_Guide_to.1341   English
# markmark.Adams.Watership_Down.1342             English
# Addison.Spectator
# ...                                                ...  ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                                                                           notes  \
# id
# markmark.Achebe.Things_Fall_Apart.1339
# markmark.Acker.In_Memoriam_to_Identity.1340
# markmark.Adams.The_Hitchhikers_Guide_to.1341  based on the author's radio series of the same...
# markmark.Adams.Watership_Down.1342
# Addison.Spectator
# ...                                                                                         ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                              num_words ocr_accuracy source  \
# id
# markmark.Achebe.Things_Fall_Apart.1339           56920     0.832537
# markmark.Acker.In_Memoriam_to_Identity.1340      75893     0.798361
# markmark.Adams.The_Hitchhikers_Guide_to.1341     56955     0.756316
# markmark.Adams.Watership_Down.1342              159885     0.767095
# Addison.Spectator
# ...                                                ...          ...    ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
#                                              subcorpus
# id
# markmark.Achebe.Things_Fall_Apart.1339
# markmark.Acker.In_Memoriam_to_Identity.1340
# markmark.Adams.The_Hitchhikers_Guide_to.1341
# markmark.Adams.Watership_Down.1342
# Addison.Spectator
# ...                                                ...
# Unknown.King James Bible.New Testament
# Julian of Norwich.Divine Love
# Bible.Leviticus.KJV
# Bible.Numbers.KJV
# Bible.Deuteronomy.KJV
#
# [927 rows x 29 columns]

# %%
# join
alldf=df.set_index('id').join(meta,rsuffix='_meta',how='inner').reset_index()
alldf['major_genre']=alldf['major_genre'].apply(lambda x: x if x else 'Unknown')
alldf['year_orig']=alldf['year']
alldf['year']=alldf['year_orig'].apply(edityear)
alldf['dec']=[x//10*10 for x in alldf['year']]
alldf.loc[alldf['canon_genre'].str.strip()=="", "major_genre"]="Unknown"
alldf
# Out:
#                                                id  contrast    source period  \
# 0                               Addison.Spectator  Abs-Conc  LSN-Hapt    C16
# 1                               Addison.Spectator  Abs-Conc  LSN-Imag    C16
# 2                               Addison.Spectator  Abs-Conc  MRC-Conc    C16
# 3                               Addison.Spectator  Abs-Conc  MRC-Imag    C16
# 4                               Addison.Spectator  Abs-Conc   MT-Conc    C16
# ...                                           ...       ...       ...    ...
# 57003  markmark.du Maurier.The_Kings_General.1692  Abs-Conc  MRC-Imag   orig
# 57004  markmark.du Maurier.The_Kings_General.1692  Abs-Conc   MT-Conc   orig
# 57005  markmark.du Maurier.The_Kings_General.1692  Abs-Conc  PAV-Conc   orig
# 57006  markmark.du Maurier.The_Kings_General.1692  Abs-Conc  PAV-Imag   orig
# 57007  markmark.du Maurier.The_Kings_General.1692  Abs-Conc    Median   orig
#
#            mean    median           sum       std    size              author  \
# 0     -0.161186 -0.326418 -18015.900324  0.921423  111771             Addison
# 1     -0.242359 -0.393117 -27088.681450  0.948415  111771             Addison
# 2     -0.315548 -0.456016 -35269.130002  0.971550  111771             Addison
# 3     -0.167786 -0.300058 -18753.553385  0.988876  111771             Addison
# 4     -0.434885 -0.564527 -48607.533122  0.907902  111771             Addison
# ...         ...       ...           ...       ...     ...                 ...
# 57003  0.399013  0.419598   6035.475149  0.855050   15126  du Maurier, Daphne
# 57004  0.517047  0.704287  15879.541506  0.959675   30712  du Maurier, Daphne
# 57005  0.206936  0.839767    720.136055  1.051192    3480  du Maurier, Daphne
# 57006  0.349027  0.892205   1203.095689  0.985313    3447  du Maurier, Daphne
# 57007  0.378744  0.489724  11733.098753  0.845168   30979  du Maurier, Daphne
#
#        ...     name_title   nation note notes num_words ocr_accuracy  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...            ...      ...  ...   ...       ...          ...
# 57003  ...  Lady Browning  English               130924     0.761793
# 57004  ...  Lady Browning  English               130924     0.761793
# 57005  ...  Lady Browning  English               130924     0.761793
# 57006  ...  Lady Browning  English               130924     0.761793
# 57007  ...  Lady Browning  English               130924     0.761793
#
#       source_meta subcorpus year_orig   dec
# 0                                1711  1710
# 1                                1711  1710
# 2                                1711  1710
# 3                                1711  1710
# 4                                1711  1710
# ...           ...       ...       ...   ...
# 57003                            1946  1940
# 57004                            1946  1940
# 57005                            1946  1940
# 57006                            1946  1940
# 57007                            1946  1940
#
# [57008 rows x 40 columns]

# %%
# alldf.groupby('year').sample(n=1)
figdf=alldf.groupby(['major_genre','canon_genre','id']).mean().reset_index()
figdf['mean_z']=(figdf['mean'] - figdf['mean'].mean()) / figdf['mean'].std()
figdf['median_z']=(figdf['median'] - figdf['median'].mean()) / figdf['median'].std()
figdf
# Out:
#     major_genre          canon_genre  \
# 0      Allegory               Bunyan
# 1      Allegory               Bunyan
# 2      Allegory               Bunyan
# 3      Allegory      “Piers Plowman”
# 4      Dialogue             Dialogue
# ..          ...                  ...
# 920       Verse          Shakespeare
# 921       Verse              Spenser
# 922       Verse  “Dream of the Rood”
# 923       Verse      “Knight’s Tale”
# 924       Verse      “Miller’s Tale”
#
#                                                  id      mean    median  \
# 0                 chadwyck.Bunyan.The_Holy_War.0937 -0.207654 -0.276156
# 1    chadwyck.Bunyan.The_Pilgrims_Progress_Par.0939 -0.165861 -0.225098
# 2    chadwyck.Bunyan.The_Pilgrims_Progress_Par.0940 -0.066151 -0.102492
# 3                                Anon.Piers Plowman -0.120583 -0.220408
# 4      chadwyck.Breton.A_Mad_VVorld_my_masters.0935 -0.202583 -0.309875
# ..                                              ...       ...       ...
# 920                    Shakespeare.Venus and Adonis  0.201234  0.218789
# 921                      Spenser.FaerieQueene.Book1  0.094028  0.078458
# 922                    AngloSaxon.Dream of the Rood  0.024693 -0.038518
# 923        Chaucer.Canterbury_Tales.02.Knights_Tale  0.105297  0.086522
# 924        Chaucer.Canterbury_Tales.03.Millers_Tale  0.332899  0.364653
#
#              sum       std          size    year  year_orig     dec    mean_z  \
# 0   -4802.800457  0.855433  21644.553571  1682.0       1682  1680.0 -0.673039
# 1   -1833.728301  0.907247  10336.107143  1678.0       1678  1670.0 -0.531463
# 2    -824.109685  0.892749  10753.250000  1684.0       1684  1680.0 -0.193693
# 3    -806.101713  0.909724   6540.964286  1549.0       1370  1540.0 -0.378082
# 4   -2525.014767  0.868484  12002.678571  1635.0       1635  1630.0 -0.655860
# ..           ...       ...           ...     ...        ...     ...       ...
# 920   676.648392  0.894911   3404.785714  1597.0       1593  1590.0  0.712080
# 921  1455.852037  0.865355  15500.303571  1596.0       1590  1590.0  0.348917
# 922     5.430471  0.908847    408.750000  1516.0        900  1510.0  0.114043
# 923   458.232872  0.914372   4393.142857  1552.0       1400  1550.0  0.387094
# 924   460.976947  0.930428   1392.535714  1552.0       1400  1550.0  1.158100
#
#      median_z
# 0   -0.632040
# 1   -0.490993
# 2   -0.152292
# 3   -0.478036
# 4   -0.725189
# ..        ...
# 920  0.735246
# 921  0.347584
# 922  0.024436
# 923  0.369860
# 924  1.138197
#
# [925 rows x 13 columns]

# %%
# Plot
p9.options.dpi=600
yname='mean_z'
jitter=1
version='v13'
maxval=2.25
minval=-2.25

# data
figdf0 = figdf.sample(frac=1)
if maxval: figdf0[yname]=figdf0[yname].apply(lambda x: x if x<maxval else maxval)
if minval: figdf0[yname]=figdf0[yname].apply(lambda x: x if x>minval else minval)

# split    
figdf_canon = figdf0.groupby(['major_genre','canon_genre']).mean().reset_index()
figdf_all=figdf0.groupby('id').mean().reset_index()

# start
fig = p9.ggplot(
    p9.aes(x='year',y=yname),
    data=figdf_all
)

# style
fig+=p9.theme_classic()

# axes
fig+=p9.geom_vline(xintercept=breaks,color='silver')
fig+=p9.geom_vline(xintercept=prebreaks,color='silver')
fig+=p9.geom_hline(yintercept=0.0,color='gray')

# points
fig+=p9.geom_point(
    size=.5,
    alpha=0.5,
#     data=figdf_all.query('1485<=year_orig<2020')
)



# trend
fig+=p9.geom_smooth(
    span=0.3,
    se=True,
    method='loess',
    alpha=0.25,
    color='gray',
#     data=figdf_all.query('1580<=year_orig<2020')
    data=figdf_all.query('1600<=year_orig<2000')
)

# labels
fig+=p9.geom_label(p9.aes(label='canon_genre'),size=6,data=figdf_canon,
                   adjust_text=dict(expand_text=(0.5,0.05)) if jitter else None
                  )

# # legends
# fig+=p9.scale_shape_manual(shapes,show_legend=True,guide='legend')

# scales
fig+=p9.scale_x_continuous(
    breaks=prebreaks+breaks,
    labels=[(f'{x*-1} BC' if x<0 else f'{x} AD') if x<=0 else str(x)
            for x in prebreak_cuts+breaks],
)

# show
fig+=p9.labs(
    title='Concreteness in the (mostly British) canon',
    x='Year',
    y=f'{yname.title().split("_")[0]} concreteness score (z)'
)
fig+=p9.ylim(minval,maxval)
fig.save(f'''../../figures/fig.concscores.canon.{yname}.{"j" if jitter else "x"}.{version}.png''')
fig
# Out:
# <ggplot: (8726853498105)>
